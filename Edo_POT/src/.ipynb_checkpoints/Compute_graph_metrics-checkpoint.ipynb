# %%
import pandas as pd # For creating dataframes and calculating correlation matrices.
from pandas.api.types import CategoricalDtype # For correctly setting some dataframe colummns as being of categorical type

from pathlib import Path # For defining the path directory in which the data is stored

import seaborn as sn   # For creating visual representations
import matplotlib.pyplot as plt # of correlation matrices.

import numpy as np #For numerical opertions

import networkx as nx
import matplotlib.cm as cm

# %%
complexity_data_mex_pairs_socioecon=pd.read_csv('../output_data/complexity_data_mex_pairs_socioecon.csv')
complexity_data_mex_pairs_socioecon
# Out:
#         Unnamed: 0  year_pair   location_code  Product  export       eci  \
# 0                0  2004_2009  Aguascalientes   112511  1004.0  0.256317
# 1                1  2004_2009  Aguascalientes   112512  1004.0  0.256317
# 2                2  2004_2009  Aguascalientes   114111  1004.0  0.256317
# 3                3  2004_2009  Aguascalientes   114112  1004.0  0.256317
# 4                4  2004_2009  Aguascalientes   114113  1004.0  0.256317
# ...            ...        ...             ...      ...     ...       ...
# 101467      101467  2004_2019       Zacatecas   813110  1004.0 -0.963458
# 101468      101468  2004_2019       Zacatecas   813120  1004.0 -0.963458
# 101469      101469  2004_2019       Zacatecas   813130  1004.0 -0.963458
# 101470      101470  2004_2019       Zacatecas   813140  1004.0 -0.963458
# 101471      101471  2004_2019       Zacatecas   813230  1004.0 -0.963458
#
#              pci   density       coi       cog      rca1      rca2  \
# 0      -1.921854  0.324795  0.742236 -0.078885  0.000000  0.000000
# 1      -1.381170  0.375059  0.742236  0.063390  0.000000  0.000000
# 2      -2.459290  0.341204  0.742236 -0.340686  0.000000  0.000000
# 3      -1.305625  0.265136  0.742236  0.040427  0.000000  0.000000
# 4       1.981890  0.240150  0.742236  0.568119  0.000000  0.000000
# ...          ...       ...       ...       ...       ...       ...
# 101467 -2.216330  0.491777 -0.546682 -0.000000  1.972732  1.430538
# 101468 -2.406734  0.492183 -0.546682 -0.000000  3.039947  1.576602
# 101469 -1.978651  0.367556 -0.546682  0.334113  0.000000  0.994844
# 101470 -0.620734  0.263436 -0.546682  0.898940  0.000000  0.000000
# 101471 -2.100393  0.454779 -0.546682  0.027243  0.916386  1.231625
#
#                      M  M_num  GPDperCAP  ied
# 0       Underdeveloped      0   0.118784  0.0
# 1       Underdeveloped      0   0.118784  0.0
# 2       Underdeveloped      0   0.118784  0.0
# 3       Underdeveloped      0   0.118784  0.0
# 4       Underdeveloped      0   0.118784  0.0
# ...                ...    ...        ...  ...
# 101467             NaN      2   0.077258  0.0
# 101468             NaN      2   0.077258  0.0
# 101469  Underdeveloped      0   0.077258  0.0
# 101470  Underdeveloped      0   0.077258  0.0
# 101471             NaN      2   0.077258  0.0
#
# [101472 rows x 16 columns]

# %%
Estados=complexity_data_mex_pairs_socioecon['location_code'].unique()

years_pairs=complexity_data_mex_pairs_socioecon['year_pair'].unique()

# %%
product=112511

year_pair='2004_2019'

complexity_data_year=complexity_data_mex_pairs_socioecon.loc[complexity_data_mex_pairs_socioecon['year_pair']==year_pair]

complexity_data_year.loc[complexity_data_year['Product']==prod]

complexity_data_mex_pairs_socioecon.loc[(complexity_data_mex_pairs_socioecon['year_pair']==year_pair)&
                                               (complexity_data_mex_pairs_socioecon['Product']==product)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1788\62343264.py in <module>
#       5 complexity_data_year=complexity_data_mex_pairs_socioecon.loc[complexity_data_mex_pairs_socioecon['year_pair']==year_pair]
#       6
# ----> 7 complexity_data_year.loc[complexity_data_year['Product']==prod]
#       8
#       9 complexity_data_mex_pairs_socioecon.loc[(complexity_data_mex_pairs_socioecon['year_pair']==year_pair)&
#
# NameError: name 'prod' is not defined

# %%
for year_pair in years_pairs:
    
    print(year_pair)

    complexity_data_year=complexity_data_mex_pairs_socioecon.loc[complexity_data_mex_pairs_socioecon['year_pair']==year_pair]
    
    products=sorted(complexity_data_year['Product'].unique())
    
    year_str=year_pair[0:4]
    
    G=nx.read_gexf('../output_data/Graphs_files/'+year_str+".gexf")
    
    Nodes_list=list(G.nodes)
    #Graph attributes
    weights = nx.get_edge_attributes(G,'weight').values()
    # Nodes Metrics
    Nodes_Degree_Centrality_dict = dict(nx.degree_centrality(G))
    Nodes_Eigenvector_Centrality_dict = dict(nx.eigenvector_centrality(G,weight='weight'))
    Nodes_Closeness_Centrality_dict = dict(nx.closeness_centrality(G),distance='distance')
    
    for product in products:
        print(product, end=', ')
        
        complexity_data_mex_pairs_socioecon.loc[(complexity_data_mex_pairs_socioecon['year_pair']==year_pair)&
                                               (complexity_data_mex_pairs_socioecon['Product']==product),
                                                'degree_centrality']=Nodes_Degree_Centrality_dict[str(product)]
        
        complexity_data_mex_pairs_socioecon.loc[(complexity_data_mex_pairs_socioecon['year_pair']==year_pair)&
                                               (complexity_data_mex_pairs_socioecon['Product']==product),
                                                'eigenvecor_centrality']=Nodes_Eigenvector_Centrality_dict[str(product)]
        
        complexity_data_mex_pairs_socioecon.loc[(complexity_data_mex_pairs_socioecon['year_pair']==year_pair)&
                                               (complexity_data_mex_pairs_socioecon['Product']==product),
                                                'closeness_centrality']=Nodes_Closeness_Centrality_dict[str(product)]

        
        
        
complexity_data_mex_pairs_socioecon

# %%
complexity_data_mex_pairs_socioecon.loc[(complexity_data_mex_pairs_socioecon['year_pair']==year_pair)&
                                               (complexity_data_mex_pairs_socioecon['Product']==product)]

# %%
complexity_data_mex_pairs_socioecon.to_csv('../output_data/complexity_data_mex_pairs_all.csv')
